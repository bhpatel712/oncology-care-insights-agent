# %% [markdown]
# # 02 — Retrieval Validation
# Manually test Azure AI Search retrieval quality before wiring into the agent.

# %%
# TODO Week 2: Test retrieval against 15 sample questions per cancer type
# from azure.search.documents import SearchClient
